# %%
import math
import pandas as pd
import numpy as np

from pathlib import Path

import matplotlib.pyplot as plt

# %%
DATA_DIR = Path.cwd().parent / "data"
CSV_CV_TRANSISTOR = DATA_DIR / "cv-transistor.csv"

# %%
cv_transistor_df = pd.read_csv(CSV_CV_TRANSISTOR).T.reset_index()
cv_transistor_df.columns = ["V", "I"]
cv_transistor_df["V"] = cv_transistor_df["V"].astype(float)
cv_transistor_df["I"] = cv_transistor_df["I"].astype(float)

cv_transistor_df
# Out:
#       V     I
# 0   0.0  7.40
# 1  -0.1  7.35
# 2  -0.2  7.30
# 3  -0.3  7.20
# 4  -0.4  7.10
# 5  -0.5  7.00
# 6  -0.6  6.80
# 7  -0.7  6.40
# 8  -0.8  5.80
# 9  -0.9  5.20
# 10 -1.0  4.60
# 11 -1.1  4.00
# 12 -1.2  3.20
# 13 -1.3  2.60
# 14 -1.4  2.10
# 15 -1.5  1.60
# 16 -1.6  1.20
# 17 -1.7  0.70
# 18 -1.8  0.40
# 19 -1.9  0.10
# 20 -2.0  0.00
# 21 -2.1  0.00

# %%
plt.title("Volt-Current characteristic of a field-effect transistor")

X = cv_transistor_df["V"]
Y = cv_transistor_df["I"]

plt.plot(X, Y, linewidth=1)

plt.xlabel("V, Volts")
plt.ylabel("I, mAmpers")

plt.tight_layout()
plt.show()
